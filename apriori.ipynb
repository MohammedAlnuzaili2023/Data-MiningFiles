# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
data=pd.read_csv("basket_analysis.csv")

# %%
data
# Out:
#      Unnamed: 0  Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0             0  False   True   False   False   True   True  False       True
# 1             1  False  False   False   False  False  False  False      False
# 2             2   True  False    True   False  False   True  False       True
# 3             3  False  False    True    True  False   True  False      False
# 4             4   True   True   False   False  False  False  False      False
# ..          ...    ...    ...     ...     ...    ...    ...    ...        ...
# 994         994  False   True   False   False  False  False   True      False
# 995         995   True  False   False   False   True  False  False      False
# 996         996   True  False   False   False   True   True  False      False
# 997         997  False  False    True    True   True  False   True       True
# 998         998  False  False   False   False  False  False  False      False
#
# ...

# %%
df=data.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#      Apple  Bread  Butter  Cheese   Corn   Dill   Eggs  Ice cream  \
# 0    False   True   False   False   True   True  False       True
# 1    False  False   False   False  False  False  False      False
# 2     True  False    True   False  False   True  False       True
# 3    False  False    True    True  False   True  False      False
# 4     True   True   False   False  False  False  False      False
# ..     ...    ...     ...     ...    ...    ...    ...        ...
# 994  False   True   False   False  False  False   True      False
# 995   True  False   False   False   True  False  False      False
# 996   True  False   False   False   True   True  False      False
# 997  False  False    True    True   True  False   True       True
# 998  False  False   False   False  False  False  False      False
#
#      Kidney Beans   Milk  Nutmeg  Onion  Sugar  Unicorn  Yogurt  chocolate
# 0           False  False   False  False   True    False    True       True
# ...

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
from mlxtend.frequent_patterns import apriori

# %%
frequent_skillsets=apriori(df, min_support=0.17, use_colnames=True)
frequent_skillsets
# Out:
#       support              itemsets
# 0    0.383383               (Apple)
# 1    0.384384               (Bread)
# 2    0.420420              (Butter)
# 3    0.404404              (Cheese)
# 4    0.407407                (Corn)
# ..        ...                   ...
# 115  0.191191       (Sugar, Yogurt)
# 116  0.188188    (Sugar, chocolate)
# 117  0.184184     (Unicorn, Yogurt)
# 118  0.186186  (Unicorn, chocolate)
# 119  0.198198   (chocolate, Yogurt)
#
# [120 rows x 2 columns]

# %%
from mlxtend.frequent_patterns import association_rules

# %%
res=association_rules(frequent_skillsets, metric="confidence", min_threshold=0.47)
res=res[['antecedents','consequents','confidence']]
res = res.sort_values(by="confidence", ascending=False)
res
# Out:
#     antecedents     consequents  confidence
# 53       (Milk)     (chocolate)    0.520988
# 9   (Ice cream)        (Butter)    0.504878
# 7       (Bread)        (Yogurt)    0.502604
# 52  (chocolate)          (Milk)    0.501188
# 35       (Dill)     (chocolate)    0.500000
# ..          ...             ...         ...
# 65     (Yogurt)     (chocolate)    0.471429
# 6       (Bread)     (Ice cream)    0.471354
# 48     (Nutmeg)  (Kidney Beans)    0.471322
# 51    (Unicorn)          (Milk)    0.470437
# 64  (chocolate)        (Yogurt)    0.470309
#
# [66 rows x 3 columns]

# %%
import re

for index, row in res.iterrows():
    antecedents = ', '.join([re.sub(r'skill_', '', item).replace('_', ' ').title() for item in row['antecedents']])
    consequents = ', '.join([re.sub(r'skill_', '', item).replace('_', ' ').title() for item in row['consequents']])
    confidence = round(row['confidence'], 3)
    print(f"{antecedents} -> {consequents}. Confidence = {confidence}")
# Out:
# Milk -> Chocolate. Confidence = 0.521
# Ice Cream -> Butter. Confidence = 0.505
# Bread -> Yogurt. Confidence = 0.503
# Chocolate -> Milk. Confidence = 0.501
# Dill -> Chocolate. Confidence = 0.5
# Kidney Beans -> Butter. Confidence = 0.495
# Cheese -> Kidney Beans. Confidence = 0.495
# Nutmeg -> Butter. Confidence = 0.494
# Butter -> Ice Cream. Confidence = 0.493
# Ice Cream -> Chocolate. Confidence = 0.493
# Milk -> Kidney Beans. Confidence = 0.491
# Apple -> Butter. Confidence = 0.491
# Kidney Beans -> Cheese. Confidence = 0.49
# Milk -> Butter. Confidence = 0.489
# Onion -> Butter. Confidence = 0.489
# Apple -> Yogurt. Confidence = 0.488
# Kidney Beans -> Milk. Confidence = 0.488
# Onion -> Chocolate. Confidence = 0.486
# Nutmeg -> Onion. Confidence = 0.486
# Apple -> Corn. Confidence = 0.486
# Eggs -> Yogurt. Confidence = 0.484
# Onion -> Nutmeg. Confidence = 0.484
# Dill -> Onion. Confidence = 0.482
# Bread -> Chocolate. Confidence = 0.482
# Nutmeg -> Sugar. Confidence = 0.481
# ...
