# %%
import pandas as pd

# %%
df=pd.read_csv("League of Legends Champion Stats 12.12.csv")

# %%
df.head()
# Out:
#      Name     Class Role Tier  Score  Trend   Win %  Role %  Pick %   Ban %  \
# 0  Aatrox   Fighter  TOP  God  68.69  -0.68  48.87%  92.15%   7.49%   5.55%
# 1    Ahri      Mage  MID  God  73.09  -0.63  50.42%  94.37%  10.14%   7.85%
# 2   Akali  Assassin  MID    S  60.41   1.74  49.24%  69.81%   6.74%  11.72%
# 3   Akali  Assassin  TOP    C  40.98  -2.85  46.38%  29.18%   2.78%  11.72%
# 4  Akshan  Marksman  MID    A  49.07   2.17  50.64%  57.12%   2.85%   7.17%
#
#     KDA
# 0  1.95
# 1  2.65
# 2  2.42
# 3  2.05
# 4  2.24

# %%
mask = df['Tier'] == 'God'

# %%
df = df[~mask]

# %%
df
# Out:
#         Name     Class     Role Tier  Score  Trend   Win %  Role % Pick %  \
# 2      Akali  Assassin      MID    S  60.41   1.74  49.24%  69.81%  6.74%
# 3      Akali  Assassin      TOP    C  40.98  -2.85  46.38%  29.18%  2.78%
# 4     Akshan  Marksman      MID    A  49.07   2.17  50.64%  57.12%  2.85%
# 5     Akshan  Marksman      TOP    B  42.52   0.56  50.31%  33.86%  1.64%
# 6    Alistar      Tank  SUPPORT    C  40.14  -2.86  48.92%  95.81%  2.50%
# ..       ...       ...      ...  ...    ...    ...     ...     ...    ...
# 232    Ziggs      Mage      ADC    D  33.05  -2.03  51.37%  56.10%  1.34%
# 233   Zilean   Support      MID    A  53.11   0.42  52.72%  18.12%  0.87%
# 234   Zilean   Support  SUPPORT    B  44.15  -5.03  48.37%  77.82%  3.31%
# 235      Zoe      Mage      MID    B  47.52  -0.73  48.18%  91.45%  3.58%
# 236     Zyra      Mage  SUPPORT    A  51.97   2.58  54.54%  87.62%  3.15%
#
#       Ban %   KDA
# 2    11.72%  2.42
# 3    11.72%  2.05
# 4     7.17%  2.24
# ...

# %%
df.to_csv("League of Legends Champion Stats 12.12_mod.csv")

# %%
df=pd.read_csv("League of Legends Champion Stats 12.12_mod.csv")

# %%
df
# Out:
#      Unnamed: 0     Name     Class     Role Tier  Score  Trend   Win %  \
# 0             0    Akali  Assassin      MID    S  60.41   1.74  49.24%
# 1             1    Akali  Assassin      TOP    C  40.98  -2.85  46.38%
# 2             2   Akshan  Marksman      MID    A  49.07   2.17  50.64%
# 3             3   Akshan  Marksman      TOP    B  42.52   0.56  50.31%
# 4             4  Alistar      Tank  SUPPORT    C  40.14  -2.86  48.92%
# ..          ...      ...       ...      ...  ...    ...    ...     ...
# 209         209    Ziggs      Mage      ADC    D  33.05  -2.03  51.37%
# 210         210   Zilean   Support      MID    A  53.11   0.42  52.72%
# 211         211   Zilean   Support  SUPPORT    B  44.15  -5.03  48.37%
# 212         212      Zoe      Mage      MID    B  47.52  -0.73  48.18%
# 213         213     Zyra      Mage  SUPPORT    A  51.97   2.58  54.54%
#
#      Role % Pick %   Ban %   KDA
# 0    69.81%  6.74%  11.72%  2.42
# 1    29.18%  2.78%  11.72%  2.05
# ...

# %%
df=df.drop('Unnamed: 0', axis=1)

# %%
df
# Out:
#         Name     Class     Role Tier  Score  Trend   Win %  Role % Pick %  \
# 0      Akali  Assassin      MID    S  60.41   1.74  49.24%  69.81%  6.74%
# 1      Akali  Assassin      TOP    C  40.98  -2.85  46.38%  29.18%  2.78%
# 2     Akshan  Marksman      MID    A  49.07   2.17  50.64%  57.12%  2.85%
# 3     Akshan  Marksman      TOP    B  42.52   0.56  50.31%  33.86%  1.64%
# 4    Alistar      Tank  SUPPORT    C  40.14  -2.86  48.92%  95.81%  2.50%
# ..       ...       ...      ...  ...    ...    ...     ...     ...    ...
# 209    Ziggs      Mage      ADC    D  33.05  -2.03  51.37%  56.10%  1.34%
# 210   Zilean   Support      MID    A  53.11   0.42  52.72%  18.12%  0.87%
# 211   Zilean   Support  SUPPORT    B  44.15  -5.03  48.37%  77.82%  3.31%
# 212      Zoe      Mage      MID    B  47.52  -0.73  48.18%  91.45%  3.58%
# 213     Zyra      Mage  SUPPORT    A  51.97   2.58  54.54%  87.62%  3.15%
#
#       Ban %   KDA
# 0    11.72%  2.42
# 1    11.72%  2.05
# 2     7.17%  2.24
# ...

# %%
df.to_csv("League of Legends Champion Stats 12.12_mod.csv")
